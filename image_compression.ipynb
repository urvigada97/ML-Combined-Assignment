# %%
import numpy as np 
from sklearn.cluster import KMeans
from scipy import misc
import matplotlib.pyplot as plt

# %%
face = misc.face(gray=True)
face.shape
# Out:
# (768, 1024)

# %%
n_clusters = 5
## Reshaping the matrix to 1-dim
X = face.reshape((-1, 1))
X.shape
# Out:
# (786432, 1)

# %%
X
# Out:
# array([[114],
#        [130],
#        [145],
#        ...,
#        [142],
#        [141],
#        [140]], dtype=uint8)

# %%
k_Means = KMeans(n_clusters=n_clusters)
k_Means.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
k_Means.cluster_centers_
# Out:
# array([[114.99362851],
#        [ 27.62031146],
#        [194.13840989],
#        [ 75.41095451],
#        [153.31393344]])

# %%
k_Means.labels_
# Out:
# array([0, 0, 4, ..., 4, 4, 4])

# %%
## Reshaping the 2-dim array to 1-dim array
k_Means.cluster_centers_.squeeze()
# Out:
# array([114.99362851,  27.62031146, 194.13840989,  75.41095451,
#        153.31393344])

# %%
values = k_Means.cluster_centers_.squeeze()
labels = k_Means.labels_

# %%
face_compressed = np.choose(labels, values)
face_compressed.shape
# Out:
# (786432,)

# %%
## Reshaping array to the original shape
face_compressed.shape = face.shape

# %%
vmin = face.min()
vmax = face.max()

# %%
## Original face
plt.figure(1)
plt.imshow(face, cmap=plt.cm.gray, vmin=vmin, vmax=256)

# %%
## Original face
plt.figure(1)
plt.imshow(face_compressed, cmap=plt.cm.gray, vmin=vmin, vmax=vmax)
